# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Visão Geral

# %%
df = pd.read_csv('biased_leukemia_dataset.csv')
display(df)
# Out:
#         Patient_ID  Age  Gender    Country  WBC_Count  RBC_Count  \
# 0                1   52    Male      China       2698       5.36
# 1                2   15  Female      China       4857       4.81
# 2                3   72    Male     France       9614       5.17
# 3                4   61    Male     Brazil       6278       5.41
# 4                5   21    Male     Brazil       8342       4.78
# ...            ...  ...     ...        ...        ...        ...
# 143189      143190   11    Male  Argentina       7525       5.30
# 143190      143191   77  Female      China       7258       4.48
# 143191      143192   22  Female        USA       6321       4.94
# 143192      143193   14  Female      India       8039       5.45
# 143193      143194   20    Male     France       7372       5.19
#
#         Platelet_Count  Hemoglobin_Level  Bone_Marrow_Blasts Genetic_Mutation  \
# 0               262493              12.2                  72              Yes
# ...

# %%
display(df.describe())
# Out:
#          Patient_ID            Age      WBC_Count      RBC_Count  \
# count  143194.00000  143194.000000  143194.000000  143194.000000
# mean    71597.50000      44.945200    7001.289879       4.998193
# std     41336.69156      25.737805    2007.444410       0.500298
# min         1.00000       1.000000   -1602.000000       2.940000
# 25%     35799.25000      23.000000    5644.250000       4.660000
# 50%     71597.50000      45.000000    7007.000000       5.000000
# 75%    107395.75000      67.000000    8352.000000       5.340000
# max    143194.00000      89.000000   15586.000000       7.150000
#
#        Platelet_Count  Hemoglobin_Level  Bone_Marrow_Blasts            BMI
# count   143194.000000     143194.000000       143194.000000  143194.000000
# mean    249933.012137         13.498334           49.547984      24.990679
# std      49842.308243          1.996714           28.837607       4.999786
# min      46069.000000          4.700000            0.000000       2.800000
# ...

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143194 entries, 0 to 143193
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Patient_ID            143194 non-null  int64
#  1   Age                   143194 non-null  int64
#  2   Gender                143194 non-null  object
#  3   Country               143194 non-null  object
#  4   WBC_Count             143194 non-null  int64
#  5   RBC_Count             143194 non-null  float64
#  6   Platelet_Count        143194 non-null  int64
#  7   Hemoglobin_Level      143194 non-null  float64
#  8   Bone_Marrow_Blasts    143194 non-null  int64
#  9   Genetic_Mutation      143194 non-null  object
#  10  Family_History        143194 non-null  object
#  11  Smoking_Status        143194 non-null  object
#  12  Alcohol_Consumption   143194 non-null  object
#  13  Radiation_Exposure    143194 non-null  object
# ...

# %% [markdown]
# # Tratamento / Limpeza

# %%
media_wbc = df[df['WBC_Count'] >= 0]['WBC_Count'].median()
df['WBC_Count'] = df['WBC_Count'].apply(lambda x: media_wbc if x < 0 else x)

# %%
media_Bone = df[df['Bone_Marrow_Blasts'] >= 0]['Bone_Marrow_Blasts'].median()
df['Bone_Marrow_Blasts'] = df['Bone_Marrow_Blasts'].apply(lambda x: media_Bone if x <= 0 else x)

# %%
display(df.describe())
# Out:
#          Patient_ID            Age      WBC_Count      RBC_Count  \
# count  143194.00000  143194.000000  143194.000000  143194.000000
# mean    71597.50000      44.945200    7002.493275       4.998193
# std     41336.69156      25.737805    2005.191596       0.500298
# min         1.00000       1.000000      16.000000       2.940000
# 25%     35799.25000      23.000000    5646.000000       4.660000
# 50%     71597.50000      45.000000    7007.000000       5.000000
# 75%    107395.75000      67.000000    8352.000000       5.340000
# max    143194.00000      89.000000   15586.000000       7.150000
#
#        Platelet_Count  Hemoglobin_Level  Bone_Marrow_Blasts            BMI
# count   143194.000000     143194.000000       143194.000000  143194.000000
# mean    249933.012137         13.498334           50.043116      24.990679
# std      49842.308243          1.996714           28.408682       4.999786
# min      46069.000000          4.700000            1.000000       2.800000
# ...

# %% [markdown]
# # Análise

# %%
df_leukemia = df.groupby('Leukemia_Status').agg('Patient_ID').count()
display(df_leukemia)
# Out:
# Leukemia_Status
# Negative    121797
# Positive     21397
# Name: Patient_ID, dtype: int64

# %%
plt.figure(figsize=(5, 4))
sns.countplot(x='Leukemia_Status', data=df, palette='Set1')
plt.title('Leukemia Status')
plt.xlabel('Leukemia')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\João\AppData\Local\Temp\ipykernel_7164\794122772.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Leukemia_Status', data=df, palette='Set1')

# %% [markdown]
# ## Idade

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', hue='Leukemia_Status', multiple='stack', bins=89, palette='Set1')
plt.title('Age VS Leukemia')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
def category_age(age):
  if age < 13:
    return 'Children'
  elif 13 <= age < 18:
    return 'Teenager'
  elif 18 <= age < 65:
    return 'Adult'
  else:
    return 'Elderly'
  
df["Category_Age"] = df["Age"].apply(category_age)

# %%
plt.figure(figsize=(9, 6))
sns.countplot(x='Category_Age', hue='Leukemia_Status', data=df, palette='Set1')
plt.title('Category Age VS Leukemia Status')
plt.xlabel('Category Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Genero

# %%
df_gender = df.groupby('Gender').agg('Patient_ID').count()
display(df_gender)
# Out:
# Gender
# Female    57470
# Male      85724
# Name: Patient_ID, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Gender', hue='Leukemia_Status', data=df, palette='Set1')
plt.title('Leukemia Status by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## País

# %%
country_bias = df['Country'].value_counts(normalize=True) * 100
display(country_bias)
# Out:
# Country
# India           16.120089
# USA             15.906393
# Brazil          10.637317
# Russia          10.626842
# China           10.577957
# UK               2.210288
# Mexico           2.206796
# Turkey           2.183052
# South Korea      2.145341
# Canada           2.142548
# Australia        2.139056
# Sweden           2.137659
# South Africa     2.134866
# Netherlands      2.126486
# Japan            2.104837
# Norway           2.099250
# Argentina        2.095758
# France           2.095060
# Germany          2.086680
# Saudi Arabia     2.078299
# Italy            2.076204
# Spain            2.069221
# Name: proportion, dtype: float64

# %%
top_countries = df['Country'].value_counts().index

plt.figure(figsize=(12, 6))
sns.countplot(y='Country', hue='Leukemia_Status', data=df[df['Country'].isin(top_countries)], palette='Set1')
plt.title('Country VS Leukemia')
plt.xlabel('Count')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Glóbulos brancos

# %% [markdown]
# ## Glóbulos Vermelhos

# %% [markdown]
# ## Contagem de Plaquetas

# %% [markdown]
# ## Nível de hemoglobina

# %% [markdown]
# ## Explosões de Medula Óssea

# %% [markdown]
# ## Mutação genética

# %%
plt.subplots(figsize=(6, 4))
sns.countplot(x='Genetic_Mutation', hue='Leukemia_Status', data=df, palette='Set1')
plt.title('Genetic Mutation VS Leukemia Status')
plt.xlabel('Genetic Mutation')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Histórico familiar

# %%
plt.subplots(figsize=(6, 4))
sns.countplot(x='Family_History', hue='Leukemia_Status', data=df, palette='Set1')
plt.title('Family History VS Leukemia Status')
plt.xlabel('Family History')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Status de tabagismo

# %%
plt.subplots(figsize=(6, 4))
sns.countplot(x='Alcohol_Consumption', hue='Leukemia_Status', data=df, palette='Set1')
plt.title('Alcohol Consumption VS Leukemia Status')
plt.xlabel('Alcohol Consumption')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Consumo de álcool

# %%
plt.subplots(figsize=(6, 4))
sns.countplot(x='Smoking_Status', hue='Leukemia_Status', data=df, palette='Set1')
plt.title('Smoking Status VS Leukemia Status')
plt.xlabel('Smoking Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Exposição à radiação

# %% [markdown]
# ## Histórico de infecção

# %% [markdown]
# ## Índice de massa corporal

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='BMI', hue='Leukemia_Status', fill=True, common_norm=False, palette='Set1', alpha=0.6)
plt.title('BMI Distribution VS Leukemia Status')
plt.xlabel('BMI')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ## Doença crônica

# %% [markdown]
# ## Distúrbios imunológicos

# %% [markdown]
# ## Etnia

# %% [markdown]
# ## Status Socioeconômico

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Socioeconomic_Status', hue='Leukemia_Status', data=df, palette='Set1')
plt.title('Socioeconomic Status VS Leukemia Status')
plt.xlabel('Socioeconomic Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Urbano / rural

# %%
plt.figure(figsize=(7, 5))
sns.countplot(x='Urban_Rural', hue='Leukemia_Status', data=df, palette='Set1')
plt.title('Urban/Rural Areas VS Leukemia Status')
plt.xlabel('Living Area')
plt.ylabel('Count')
plt.show()
